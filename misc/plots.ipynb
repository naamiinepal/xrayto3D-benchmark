# %%
import matplotlib.pyplot as plt
import math
from xrayto3d_preprocess import get_barplot,set_style,horizontal_line

# %%
set_style()
data = {'Verse19':83.15,'LIDC':95.63,'Verse19+LIDC':92.49}
dataset_size = {'Verse19':1636,'LIDC':10150,'Verse19+LIDC':11786}
fig, ax = plt.subplots()
for key,value in data.items():
    horizontal_line(value,label='',color='k',fig=fig,ax=ax)
    plt.scatter(0,value,s=dataset_size[key]/2,label=key)
# lgnd =plt.legend(loc='best')
# #change the marker size manually for both lines
# for i in range(3):
#     lgnd.legendHandles[i]._sizes = [40]
for k in data.keys():
    plt.annotate(k,xy = (0.5,data[k]+0.5))
ax.get_xaxis().set_ticklabels([])
ax.set_xlim(-0.5,1)
ax.set_ylim(82,100)
ax.set_ylabel('DSC')
ax.set_xlabel('Dataset')
plt.tight_layout()
plt.savefig('disaggregated_by_data_source.pdf')
